# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dictionary = {
    'Name': ['Marco', 'Esteban', 'Glynda', 'Dennis', 'Frederic', 'Milly', 'Jacki', 'Jaimie', 'Coretta', 'Luna', 'Arnoldo',
             'Harold', 'Constance', 'Gidget', 'Mozell', 'Cherise', 'Darcie', 'Janeth', 'Junior', 'Tami'],
    'Age' : [12, 23, 43, 21, 23, 34, 32, 21, 18, 20, 30, 25, 27, 33, 31, 16, 34, 28, 30, 60],
    'Gender': ['M', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', np.NaN, 'M', 'F', 'F', 'F', 'M', 'F'],
    'Score': [100, 34, 88, 90, 89, 98, 79, 77, 68, 94, 99, 84, 86, 93, 97, np.NaN, 84, 73, 90, 93],
    'Phone_Num': [7785166181, 5889847559, 5958063159, 3986350245, 8584201970, 7975767585, 8673538706, 3744513004, 9117201028,
                  9825470697, 9379542186, 4255024728, 8639221387, 9427328554, 7959649422, 8219389283, 5147394162, 8385842678, 
                  5217162852, 2934442981],
    'Major': ['Computer Science', 'Computer Engineering', 'Communication Studies', 'Mathematics', 'Physics', 'Geology',
              'Biology', 'Chemistry', 'Social Studies', 'Finance', 'Floriculture', 'Physical Education', 'Government', 
              'Architecture', 'Forestry', np.nan, 'Arabic', 'Anatomy', 'Astronomy', 'Graphic Design']
    

}

# %%
MAC270 = pd.DataFrame(dictionary)

# %%
MAC270['Major'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Major, dtype: bool

# %%
MAC270.shape
# Out:
# (20, 6)

# %%
MAC270
# Out:
#          Name  Age Gender  Score   Phone_Num                  Major
# 0       Marco   12      M  100.0  7785166181       Computer Science
# 1     Esteban   23      F   34.0  5889847559   Computer Engineering
# 2      Glynda   43      F   88.0  5958063159  Communication Studies
# 3      Dennis   21      M   90.0  3986350245            Mathematics
# 4    Frederic   23      M   89.0  8584201970                Physics
# 5       Milly   34      F   98.0  7975767585                Geology
# 6       Jacki   32      F   79.0  8673538706                Biology
# 7      Jaimie   21      F   77.0  3744513004              Chemistry
# 8     Coretta   18      F   68.0  9117201028         Social Studies
# 9        Luna   20      F   94.0  9825470697                Finance
# 10    Arnoldo   30      M   99.0  9379542186           Floriculture
# 11     Harold   25      M   84.0  4255024728     Physical Education
# 12  Constance   27      M   86.0  8639221387             Government
# ...

# %%
MAC270.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Score', 'Phone_Num', 'Major'], dtype='object')

# %%
MAC270.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
MAC270['Name']
# Out:
# 0         Marco
# 1       Esteban
# 2        Glynda
# 3        Dennis
# 4      Frederic
# 5         Milly
# 6         Jacki
# 7        Jaimie
# 8       Coretta
# 9          Luna
# 10      Arnoldo
# 11       Harold
# 12    Constance
# 13       Gidget
# 14       Mozell
# 15      Cherise
# 16       Darcie
# 17       Janeth
# 18       Junior
# 19         Tami
# Name: Name, dtype: object

# %%
MAC270.head(3)
# Out:
#       Name  Age Gender  Score   Phone_Num                  Major
# 0    Marco   12      M  100.0  7785166181       Computer Science
# 1  Esteban   23      F   34.0  5889847559   Computer Engineering
# 2   Glynda   43      F   88.0  5958063159  Communication Studies

# %%
MAC270.tail(3)
# Out:
#       Name  Age Gender  Score   Phone_Num           Major
# 17  Janeth   28      F   73.0  8385842678         Anatomy
# 18  Junior   30      M   90.0  5217162852       Astronomy
# 19    Tami   60      F   93.0  2934442981  Graphic Design

# %%
emplid = [981016, 187056, 449794, 479778, 849075, 773688, 790439, 612483, 783866, 772357, 462036, 261869, 257178, 431187,
           143724, 974155, 966230, 438931, 894227, 830529]

# %%
MAC270['new_col'] = emplid

# %%
MAC270
# Out:
#          Name  Age Gender  Score   Phone_Num                  Major  new_col
# 0       Marco   12      M  100.0  7785166181       Computer Science   981016
# 1     Esteban   23      F   34.0  5889847559   Computer Engineering   187056
# 2      Glynda   43      F   88.0  5958063159  Communication Studies   449794
# 3      Dennis   21      M   90.0  3986350245            Mathematics   479778
# 4    Frederic   23      M   89.0  8584201970                Physics   849075
# 5       Milly   34      F   98.0  7975767585                Geology   773688
# 6       Jacki   32      F   79.0  8673538706                Biology   790439
# 7      Jaimie   21      F   77.0  3744513004              Chemistry   612483
# 8     Coretta   18      F   68.0  9117201028         Social Studies   783866
# 9        Luna   20      F   94.0  9825470697                Finance   772357
# 10    Arnoldo   30      M   99.0  9379542186           Floriculture   462036
# ...

# %%
MAC270.dtypes
# Out:
# Name          object
# Age            int64
# Gender        object
# Score        float64
# Phone_Num      int64
# Major         object
# new_col        int64
# dtype: object

# %%
MAC270.replace(['NaN'], np.NaN )
# Out:
#          Name  Age Gender  Score   Phone_Num                  Major  new_col
# 0       Marco   12      M  100.0  7785166181       Computer Science   981016
# 1     Esteban   23      F   34.0  5889847559   Computer Engineering   187056
# 2      Glynda   43      F   88.0  5958063159  Communication Studies   449794
# 3      Dennis   21      M   90.0  3986350245            Mathematics   479778
# 4    Frederic   23      M   89.0  8584201970                Physics   849075
# 5       Milly   34      F   98.0  7975767585                Geology   773688
# 6       Jacki   32      F   79.0  8673538706                Biology   790439
# 7      Jaimie   21      F   77.0  3744513004              Chemistry   612483
# 8     Coretta   18      F   68.0  9117201028         Social Studies   783866
# 9        Luna   20      F   94.0  9825470697                Finance   772357
# 10    Arnoldo   30      M   99.0  9379542186           Floriculture   462036
# ...

# %%
MAC270['Major'].fillna('Art')
# Out:
# 0          Computer Science
# 1      Computer Engineering
# 2     Communication Studies
# 3               Mathematics
# 4                   Physics
# 5                   Geology
# 6                   Biology
# 7                 Chemistry
# 8            Social Studies
# 9                   Finance
# 10             Floriculture
# 11       Physical Education
# 12               Government
# 13             Architecture
# 14                 Forestry
# 15                      Art
# 16                   Arabic
# 17                  Anatomy
# 18                Astronomy
# 19           Graphic Design
# Name: Major, dtype: object

# %%
MAC270.drop('new_col', axis = 1)
# Out:
#          Name  Age Gender  Score   Phone_Num                  Major
# 0       Marco   12      M  100.0  7785166181       Computer Science
# 1     Esteban   23      F   34.0  5889847559   Computer Engineering
# 2      Glynda   43      F   88.0  5958063159  Communication Studies
# 3      Dennis   21      M   90.0  3986350245            Mathematics
# 4    Frederic   23      M   89.0  8584201970                Physics
# 5       Milly   34      F   98.0  7975767585                Geology
# 6       Jacki   32      F   79.0  8673538706                Biology
# 7      Jaimie   21      F   77.0  3744513004              Chemistry
# 8     Coretta   18      F   68.0  9117201028         Social Studies
# 9        Luna   20      F   94.0  9825470697                Finance
# 10    Arnoldo   30      M   99.0  9379542186           Floriculture
# 11     Harold   25      M   84.0  4255024728     Physical Education
# 12  Constance   27      M   86.0  8639221387             Government
# ...

# %%
MAC270['Gender'].fillna('M', inplace = True)

# %%
MAC270
# Out:
#          Name  Age Gender  Score   Phone_Num                  Major  new_col
# 0       Marco   12      M  100.0  7785166181       Computer Science   981016
# 1     Esteban   23      F   34.0  5889847559   Computer Engineering   187056
# 2      Glynda   43      F   88.0  5958063159  Communication Studies   449794
# 3      Dennis   21      M   90.0  3986350245            Mathematics   479778
# 4    Frederic   23      M   89.0  8584201970                Physics   849075
# 5       Milly   34      F   98.0  7975767585                Geology   773688
# 6       Jacki   32      F   79.0  8673538706                Biology   790439
# 7      Jaimie   21      F   77.0  3744513004              Chemistry   612483
# 8     Coretta   18      F   68.0  9117201028         Social Studies   783866
# 9        Luna   20      F   94.0  9825470697                Finance   772357
# 10    Arnoldo   30      M   99.0  9379542186           Floriculture   462036
# ...

# %% [markdown]
# # Graph scores of the students

# %%
plt.plot(MAC270['Name'], MAC270['Score'])

# %%
median = MAC270['Score'].median()

# %%
MAC270['Score'].fillna(median, inplace = True)

# %%
MAC270['Score']
# Out:
# 0     100.0
# 1      34.0
# 2      88.0
# 3      90.0
# 4      89.0
# 5      98.0
# 6      79.0
# 7      77.0
# 8      68.0
# 9      94.0
# 10     99.0
# 11     84.0
# 12     86.0
# 13     93.0
# 14     97.0
# 15     89.0
# 16     84.0
# 17     73.0
# 18     90.0
# 19     93.0
# Name: Score, dtype: float64

# %%
plt.plot(MAC270['Name'], MAC270['Score'])

# %%
MAC270.dtypes
# Out:
# Name          object
# Age            int64
# Gender        object
# Score        float64
# Phone_Num      int64
# Major         object
# new_col        int64
# dtype: object
